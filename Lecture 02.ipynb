# %% [markdown]
# <h1 align="center" style="background-color:#011f4f;
#            color:white;
#            border-radius:8px;
#            font-family:'Times New Roman', Times, serif;
#            padding:10px 15px;
#            # display:inline-block;">
#
# <b> Introduction to Machine Learning ? Cont. </b>
#
# </h1>

# %% [markdown]
# ## **Let’s Begin, Understanding the Foundations of Machine Learning**
#
# Below are the structured concepts and model explanations of my handwritten notes.
#
# These will help you understand  what is `Machine Learning`, `its types`, `Models of each types`.

# %% [markdown]
# <img src="img\IMG-20251211-WA0010.jpg" alt="" width="500">

# %% [markdown]
# <img src="img\IMG-20251211-WA0011.jpg" alt="" width="500">

# %% [markdown]
# <img src="img\IMG-20251211-WA0012.jpg" alt="" width="500">

# %% [markdown]
# <img src="img\IMG-20251211-WA0013.jpg" alt="" width="800">

# %% [markdown]
# <img src="img\IMG-20251211-WA0013.jpg" alt="" width="00">

# %% [markdown]
# <img src="img\IMG-20251211-WA0014.jpg" alt="" width="500">

# %% [markdown]
# <img src="img\IMG-20251211-WA0015.jpg" alt="" width="500">

# %% [markdown]
# <img src="img\IMG-20251211-WA0016.jpg" alt="" width="400">

# %% [markdown]
# ## <b>Problem on Linear Regression</b>
#
# - finf the prediction of X = 13 ?

# %% [markdown]
# <img src="img\IMG-20251211-WA0017.jpg" alt="" width="400">

# %% [markdown]
# <img src="img\IMG-20251211-WA0018.jpg" alt="" width="400">

# %% [markdown]
# <img src="img\IMG-20251211-WA0019.jpg" alt="" width="400">
